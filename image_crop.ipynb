# %%
# % matplotlib inline
import matplotlib.pyplot as plt
import cv2

# %%
imgg_2012 = cv2.imread('/Users/always/stats402/Stats402-SatelliteProject/2012_train.tif')

# %%
imgg_2012.shape
# Out:
# (15354, 21243, 3)

# %%
imgg_2016.shape
# Out:
# (15354, 21243, 3)

# %%
imgg_2016 = cv2.imread('/Users/always/stats402/Stats402-SatelliteProject/2016_train.tif')

# %%
#im = plt.imread('images/2012_train.tif') # too large for matplotlib

# %%
#plt.imshow(imgg) # the whole image

# %%
cropped_image = imgg[15000:, 20800:]

# %%
cv2.imwrite("Cropped Image.jpg", cropped_image) # save image
# Out:
# True

# %%
plt.imshow(cropped_image)

# %% [markdown]
# # recommended syntax to crop image

# %% [markdown]
# 2016[14854:15354,14854:15354]
# 2012[14834:15334,14854:15354]

# %%
start_x = 14854
start_y = 14854
size = 500
plt.imshow(imgg_2016[start_x: start_x + size, start_y: start_y + size])

# %%
start_x = 14834
start_y = 14854
size = 500
plt.imshow(imgg_2012[start_x: start_x + size, start_y: start_y + size])

# %% [markdown]
# 2016[14854:15354,14354:14854]
#
# 2012[14834:15334,14854:15354]

# %%
start_x = 14854
start_y = 14354
size = 500
plt.imshow(imgg_2016[start_x: start_x + size, start_y: start_y + size])

# %%
start_x = 14834
start_y = 14354
size = 500
plt.imshow(imgg_2012[start_x: start_x + size, start_y: start_y + size])

# %%
start_x = 14354
start_y = 14854
size = 500
plt.imshow(imgg_2016[start_x: start_x + size, start_y: start_y + size])

# %%
start_x = 14334
start_y = 14854
size = 500
plt.imshow(imgg_2012[start_x: start_x + size, start_y: start_y + size])

# %%
start_x = 14354
start_y = 14874
size = 480
plt.imshow(imgg_2012[start_x: start_x + size, start_y: start_y + size])

# %% [markdown]
# 4th

# %%
start_x = 13854
start_y = 14854
size = 500
plt.imshow(imgg_2016[start_x: start_x + size, start_y: start_y + size])

# %%
start_x = 13845
start_y = 14874
size = 500
plt.imshow(imgg_2012[start_x: start_x + size, start_y: start_y + size])
